# %% [markdown]
# ***Your Objective: Build a sentiment analysis model with BERT and the IMDB reviews dataset***
# # ***Before beginning, please MAKE A COPY of this notebook and work on your own copy ***
# Dataset: https://www.kaggle.com/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# Download this to your own computer
#
# **Before beginning, be sure to go to "edit -> notebook settings -> hardware accelerator -> GPU"** This will let you use google colabs GPU
#
# Please follow the structure laid out in the notebook and answer the questions
#
# Use whatever resources you need (google, stackoverflow, etc.) and feel free to copy paste and frankenstein code

# %% [markdown]
# Use whatever libraries you want (please avoid using ktrain for the deep learning bits). Some recommendations: scikit learn, pandas
#
# Useful links:
#
# https://towardsdatascience.com/sentiment-analysis-in-10-minutes-with-bert-and-hugging-face-294e8a04b671 (tensorflow)
#
# https://curiousily.com/posts/sentiment-analysis-with-bert-and-hugging-face-using-pytorch-and-python/ (pytorch)

# %%
# bert stuff
from transformers import BertTokenizer, BertConfig,AdamW, BertForSequenceClassification,get_linear_schedule_with_warmup

# %% [markdown]
# Read in your data and inspect it (what are the labels, check the balance, check training vs testing balance, remove garbage data, etc.)

# %%
# running this code will create a 'browse' button that allows you to upload the dataset to colab
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# Tokenize, encode, and truncate/pad the data. Why do we need to encode the text? Why do we need to truncate/pad the text? (Hint: BERT provides a tokenizer, encoder, and padder)

# %% [markdown]
# The tokenized, encoded, and truncated data should look like arrays of words where the words are replaced by ints and the rest are 0's based off your padding length. Ex: with a padding length of 10, the sentence "I liked this movie" might become [1, 3, 2, 4, 0, 0, 0, 0, 0, 0] (I liked this movie is represented by ints, and the rest are 0s to fit the padding length)

# %% [markdown]
# Create your attention mask. What is the use of the attention mask for BERT?

# %% [markdown]
# Split your training/test/validation data and attention masks

# %% [markdown]
# The attention mask should be an array of 1s and 0s

# %% [markdown]
# Your new and updated training, testing, and validation sets should be segmented forms of your data (ex. if you started with 2500 reviews, you might have 2000 as training, 250 as validation, 250 as testing)

# %% [markdown]
# Do the necessary housekeeping to get all your data ready for evaluation (this will be different based off whatever deep learning library you are using)

# %% [markdown]
# You will need to read in the data or store it in a specific manner to abide by the way in which the library you are using wants it

# %% [markdown]
# Build the model: Designate optimizers, layers, epochs, batch size, etc. Define each explicit parameter you designate (*check the next text cell)

# %% [markdown]
# Upon outputting the model, you should have a clear view of its components. It should match up with the parameters you set for it

# %% [markdown]
# Train! You might want to do this first and then go back and then answer the question that asks you to define the parameters so you don't have to sit in awkward silence during training (or have a nice conversation!)

# %% [markdown]
# Validate! Make a confusion matrix. What is the confusion matrix modeling?

# %% [markdown]
# You should output a confusion matrix that has rows and cols that are labeled with positive/negative or whatever encoding you used

# %% [markdown]
# Make some predictions on some sentences you come up with

# %% [markdown]
# this should give you some sentiment polarity / a binary positive or negative
